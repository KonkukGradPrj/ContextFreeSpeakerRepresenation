# %%
import IPython
IPython.display.Audio("/home/hyeons/workspace/DB/vox1_test/wav/id10270/zjwijMp0Qyw/00001.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio("/home/hyeons/workspace/DB/vox1_test/wav/id10309/rxnN8thYzEQ/00009.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
